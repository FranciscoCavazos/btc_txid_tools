# %%
# Enrich Bitcoin TXIDs with On-Chain Timestamps

This notebook loads a spreadsheet (CSV/XLSX) with a `txid` column, fetches on-chain timestamps from BigQuery's public
Bitcoin dataset, and writes an enriched output. It also includes optional cleanup steps for `from`, `to`, and `amount`.
Cell 2 — Optional installs (code, run only if needed)

# %%
# Optional installs (code, run only if needed)
# If running in a fresh environment, uncomment:
# !pip install -r ../requirements.txt
# Out:
# Requirement already satisfied: pandas in c:\users\cisco\anaconda3\lib\site-packages (from -r ../requirements.txt (line 1)) (2.2.2)
# Requirement already satisfied: pyarrow in c:\users\cisco\anaconda3\lib\site-packages (from -r ../requirements.txt (line 2)) (14.0.2)
# Collecting openpyxl (from -r ../requirements.txt (line 3))
#   Downloading openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: google-cloud-bigquery in c:\users\cisco\anaconda3\lib\site-packages (from -r ../requirements.txt (line 4)) (3.36.0)
# Requirement already satisfied: python-dotenv in c:\users\cisco\anaconda3\lib\site-packages (from -r ../requirements.txt (line 5)) (0.21.0)
# Requirement already satisfied: tqdm in c:\users\cisco\anaconda3\lib\site-packages (from -r ../requirements.txt (line 6)) (4.66.4)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\cisco\anaconda3\lib\site-packages (from pandas->-r ../requirements.txt (line 1)) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\cisco\anaconda3\lib\site-packages (from pandas->-r ../requirements.txt (line 1)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\cisco\anaconda3\lib\site-packages (from pandas->-r ../requirements.txt (line 1)) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\cisco\anaconda3\lib\site-packages (from pandas->-r ../requirements.txt (line 1)) (2023.3)
# Collecting et-xmlfile (from openpyxl->-r ../requirements.txt (line 3))
#   Downloading et_xmlfile-2.0.0-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: google-api-core<3.0.0,>=2.11.1 in c:\users\cisco\anaconda3\lib\site-packages (from google-api-core[grpc]<3.0.0,>=2.11.1->google-cloud-bigquery->-r ../requirements.txt (line 4)) (2.25.1)
# Requirement already satisfied: google-auth<3.0.0,>=2.14.1 in c:\users\cisco\anaconda3\lib\site-packages (from google-cloud-bigquery->-r ../requirements.txt (line 4)) (2.40.3)
# Requirement already satisfied: google-cloud-core<3.0.0,>=2.4.1 in c:\users\cisco\anaconda3\lib\site-packages (from google-cloud-bigquery->-r ../requirements.txt (line 4)) (2.4.3)
# Requirement already satisfied: google-resumable-media<3.0.0,>=2.0.0 in c:\users\cisco\anaconda3\lib\site-packages (from google-cloud-bigquery->-r ../requirements.txt (line 4)) (2.7.2)
# Requirement already satisfied: packaging>=24.2.0 in c:\users\cisco\anaconda3\lib\site-packages (from google-cloud-bigquery->-r ../requirements.txt (line 4)) (25.0)
# Requirement already satisfied: requests<3.0.0,>=2.21.0 in c:\users\cisco\anaconda3\lib\site-packages (from google-cloud-bigquery->-r ../requirements.txt (line 4)) (2.32.2)
# Requirement already satisfied: colorama in c:\users\cisco\anaconda3\lib\site-packages (from tqdm->-r ../requirements.txt (line 6)) (0.4.6)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in c:\users\cisco\anaconda3\lib\site-packages (from google-api-core<3.0.0,>=2.11.1->google-api-core[grpc]<3.0.0,>=2.11.1->google-cloud-bigquery->-r ../requirements.txt (line 4)) (1.70.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.19.5 in c:\users\cisco\anaconda3\lib\site-packages (from google-api-core<3.0.0,>=2.11.1->google-api-core[grpc]<3.0.0,>=2.11.1->google-cloud-bigquery->-r ../requirements.txt (line 4)) (5.29.5)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in c:\users\cisco\anaconda3\lib\site-packages (from google-api-core<3.0.0,>=2.11.1->google-api-core[grpc]<3.0.0,>=2.11.1->google-cloud-bigquery->-r ../requirements.txt (line 4)) (1.26.1)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in c:\users\cisco\anaconda3\lib\site-packages (from google-api-core[grpc]<3.0.0,>=2.11.1->google-cloud-bigquery->-r ../requirements.txt (line 4)) (1.74.0)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in c:\users\cisco\anaconda3\lib\site-packages (from google-api-core[grpc]<3.0.0,>=2.11.1->google-cloud-bigquery->-r ../requirements.txt (line 4)) (1.71.2)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\cisco\anaconda3\lib\site-packages (from google-auth<3.0.0,>=2.14.1->google-cloud-bigquery->-r ../requirements.txt (line 4)) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\cisco\anaconda3\lib\site-packages (from google-auth<3.0.0,>=2.14.1->google-cloud-bigquery->-r ../requirements.txt (line 4)) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\cisco\anaconda3\lib\site-packages (from google-auth<3.0.0,>=2.14.1->google-cloud-bigquery->-r ../requirements.txt (line 4)) (4.9.1)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in c:\users\cisco\anaconda3\lib\site-packages (from google-resumable-media<3.0.0,>=2.0.0->google-cloud-bigquery->-r ../requirements.txt (line 4)) (1.7.1)
# Requirement already satisfied: six>=1.5 in c:\users\cisco\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas->-r ../requirements.txt (line 1)) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\cisco\anaconda3\lib\site-packages (from requests<3.0.0,>=2.21.0->google-cloud-bigquery->-r ../requirements.txt (line 4)) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\cisco\anaconda3\lib\site-packages (from requests<3.0.0,>=2.21.0->google-cloud-bigquery->-r ../requirements.txt (line 4)) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\cisco\anaconda3\lib\site-packages (from requests<3.0.0,>=2.21.0->google-cloud-bigquery->-r ../requirements.txt (line 4)) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\cisco\anaconda3\lib\site-packages (from requests<3.0.0,>=2.21.0->google-cloud-bigquery->-r ../requirements.txt (line 4)) (2025.8.3)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in c:\users\cisco\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.14.1->google-cloud-bigquery->-r ../requirements.txt (line 4)) (0.6.1)
# Downloading openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
#    ---------------------------------------- 0.0/250.9 kB ? eta -:--:--
#    - -------------------------------------- 10.2/250.9 kB ? eta -:--:--
#    ------------------- -------------------- 122.9/250.9 kB 1.4 MB/s eta 0:00:01
#    ---------------------------------------- 250.9/250.9 kB 2.2 MB/s eta 0:00:00
# Downloading et_xmlfile-2.0.0-py3-none-any.whl (18 kB)
# Installing collected packages: et-xmlfile, openpyxl
# Successfully installed et-xmlfile-2.0.0 openpyxl-3.1.5

# %%
# Imports, paths, and config (code)
from pathlib import Path
import os
import sys
from typing import Optional, List

import pandas as pd
from dotenv import load_dotenv

# Project paths (this notebook lives in .../btc_txid_tools/notebooks)
BASE = Path.cwd().parent
INPUT_DIR = BASE / "data" / "input"
OUTPUT_DIR = BASE / "data" / "output"

# Access helper module
sys.path.append(str((BASE / "src").resolve()))
from bq_utils import get_bigquery_client, fetch_tx_timestamps

# Config
load_dotenv()
BQ_LOCATION = os.getenv("BQ_LOCATION", "US")
BQ_PROJECT_ID: Optional[str] = os.getenv("BQ_PROJECT_ID")
BATCH_SIZE = 5000
TIMESTAMP_COL = "timestamp"
DISABLE_BQ = False  # set True to skip BigQuery (timestamps blank)

INPUT_DIR, OUTPUT_DIR
# Out:
# (WindowsPath('C:/Users/cisco/Desktop/btc_txid_tools/data/input'),
#  WindowsPath('C:/Users/cisco/Desktop/btc_txid_tools/data/output'))

# %%
#Select input and sheet (code)
# Update these if needed
input_path = INPUT_DIR / "transactions.csv"  # or .xlsx
sheet_name = 0  # if Excel: use index or string sheet name

print("Input path:", input_path)
assert input_path.exists(), f"Not found: {input_path}"
# Out:
# Input path: C:\Users\cisco\Desktop\btc_txid_tools\data\input\transactions.csv

# %%
# Supports CSV/XLSX
if input_path.suffix.lower() == ".csv":
    df = pd.read_csv(input_path)
elif input_path.suffix.lower() in (".xlsx", ".xls"):
    df = pd.read_excel(input_path, sheet_name=sheet_name)
else:
    raise ValueError(f"Unsupported file type: {input_path.suffix}")

# Require 'txid' column
if "txid" not in df.columns:
    raise KeyError("Input must contain a 'txid' column")

print("Rows:", len(df))
df.head(10)
# Out:
# Rows: 2072
#                                                 txid  \
# 0  002740a49e16fc127b0a58a887e5ad77cc4d5114a38aa6...
# 1  002eaecebf435e9bc3e2f3c4804ee6dd89c1dc342585d2...
# 2  0038cd4166d80a95d6bf1420beb9d16c9fb5cec19fa31f...
# 3  0083abb19ca6ce1ff1dd55ffa6531fe4d88d3ec884d93e...
# 4  00934630d88a064f60a9d294de072d5fe49620f2d6d727...
# 5  00d4189eca25abcf1381bff4db78db8a8edf8f11c5deb0...
# 6  00e43489afb85a0d3bd05f3a30b2280416d7d333d52840...
# 7  00fa784235855c1923e85557be5c5b5909eadcbd199352...
# 8  0113e56efa662e7afb75ab00d3494cbd573e6334db8b61...
# 9  011c0366033ac9d0a5ca5a878a3f16f65495942b2a50d1...
#
#                                  from                                  to  \
# 0  3HLqRkgagCCeChBBmWuDkp54YR1LEz7NuK  17AuTmGhZ4HBoJtntpN9n6vHkP5LNnrt5q
# 1  3JEirUZxifRHf7FCY2Z79e3k8FMgGM9ehY  1L14Rw9G4P173tTZdMKsFPpMNY9WdiLKK7
# 2  36tGwveXwuEnmagxrraUv2XKJXeAEzP9iB  1G1yQeKMY8mH1H5v1EbmaSegpBML8T8LuR
# 3  3F14ooo4Z4BchZrFNSxF5jgssMjJcKPfay  1PsMd9HzNxfyFNRQRxsjjvvzX48EmZVn9n
# 4  3A5zJnUeZqqjrNJCAZZkKYxh6ZgdcAKps3  1Pvw3xFhAS2i58fSdSJ7ZuHXHLSe62KcKx
# 5  35wqRthgict67zRChT3euuL3Z59uMKSryv  1NCzDib1QNF8dRD2WErgV4HSZkgyci5J8Y
# 6  3CejBDbGoEPsmyjmnv1YuML4prFg6hi2rg  1P4jiBBQ4X3VAmueSv673cxEimxFfDFYMK
# 7  39pj2d5ZuzkCXV23BaG9Re6X8xD4vmhFNc  16T27MoP4tpPeK4C9dtDCZPqGdrG2YYmMP
# 8  38i9VmL9F9phFieV9HKZcBSZsW2LnVWJ49   1rJmrG2Ys22pELEHzRftdfaruxuTqU2qm
# 9  3PuTHoR6WphgBYJAwd1XfC5uc3QnpJxMWf   1yUW75KTCyDvDLUG4fqYiZ9SoQppi1UUi
#
#       amount
# 0   5.850062
# 1   7.482093
# 2   7.586615
# 3  13.204210
# 4   5.716555
# 5  59.997146
# 6  13.933099
# 7   7.499521
# 8  87.101273
# 9  32.079762

# %%
# Load dataset (code)
# Supports CSV/XLSX
if input_path.suffix.lower() == ".csv":
    df = pd.read_csv(input_path)
elif input_path.suffix.lower() in (".xlsx", ".xls"):
    df = pd.read_excel(input_path, sheet_name=sheet_name)
else:
    raise ValueError(f"Unsupported file type: {input_path.suffix}")

# Require 'txid' column
if "txid" not in df.columns:
    raise KeyError("Input must contain a 'txid' column")

print("Rows:", len(df))
df.head(10)
# Out:
# Rows: 2072
#                                                 txid  \
# 0  002740a49e16fc127b0a58a887e5ad77cc4d5114a38aa6...
# 1  002eaecebf435e9bc3e2f3c4804ee6dd89c1dc342585d2...
# 2  0038cd4166d80a95d6bf1420beb9d16c9fb5cec19fa31f...
# 3  0083abb19ca6ce1ff1dd55ffa6531fe4d88d3ec884d93e...
# 4  00934630d88a064f60a9d294de072d5fe49620f2d6d727...
# 5  00d4189eca25abcf1381bff4db78db8a8edf8f11c5deb0...
# 6  00e43489afb85a0d3bd05f3a30b2280416d7d333d52840...
# 7  00fa784235855c1923e85557be5c5b5909eadcbd199352...
# 8  0113e56efa662e7afb75ab00d3494cbd573e6334db8b61...
# 9  011c0366033ac9d0a5ca5a878a3f16f65495942b2a50d1...
#
#                                  from                                  to  \
# 0  3HLqRkgagCCeChBBmWuDkp54YR1LEz7NuK  17AuTmGhZ4HBoJtntpN9n6vHkP5LNnrt5q
# 1  3JEirUZxifRHf7FCY2Z79e3k8FMgGM9ehY  1L14Rw9G4P173tTZdMKsFPpMNY9WdiLKK7
# 2  36tGwveXwuEnmagxrraUv2XKJXeAEzP9iB  1G1yQeKMY8mH1H5v1EbmaSegpBML8T8LuR
# 3  3F14ooo4Z4BchZrFNSxF5jgssMjJcKPfay  1PsMd9HzNxfyFNRQRxsjjvvzX48EmZVn9n
# 4  3A5zJnUeZqqjrNJCAZZkKYxh6ZgdcAKps3  1Pvw3xFhAS2i58fSdSJ7ZuHXHLSe62KcKx
# 5  35wqRthgict67zRChT3euuL3Z59uMKSryv  1NCzDib1QNF8dRD2WErgV4HSZkgyci5J8Y
# 6  3CejBDbGoEPsmyjmnv1YuML4prFg6hi2rg  1P4jiBBQ4X3VAmueSv673cxEimxFfDFYMK
# 7  39pj2d5ZuzkCXV23BaG9Re6X8xD4vmhFNc  16T27MoP4tpPeK4C9dtDCZPqGdrG2YYmMP
# 8  38i9VmL9F9phFieV9HKZcBSZsW2LnVWJ49   1rJmrG2Ys22pELEHzRftdfaruxuTqU2qm
# 9  3PuTHoR6WphgBYJAwd1XfC5uc3QnpJxMWf   1yUW75KTCyDvDLUG4fqYiZ9SoQppi1UUi
#
#       amount
# 0   5.850062
# 1   7.482093
# 2   7.586615
# 3  13.204210
# 4   5.716555
# 5  59.997146
# 6  13.933099
# 7   7.499521
# 8  87.101273
# 9  32.079762

# %%
##############Optional cleanup/normalization of other columns (code)
# Examples: trim whitespace and normalize case on 'from'/'to'; coerce 'amount' numeric
for col in ["from", "to"]:
    if col in df.columns:
        df[col] = df[col].astype(str).str.strip()

if "amount" in df.columns:
    df["amount"] = pd.to_numeric(df["amount"], errors="coerce")

# Optional: drop duplicate rows (exact duplicates)
# df = df.drop_duplicates().reset_index(drop=True)

# Optional: reorder columns (put txid first)
cols = list(df.columns)
if "txid" in cols:
    cols = ["txid"] + [c for c in cols if c != "txid"]
    df = df[cols]

print("After optional cleanup:", df.shape)
df.head(5)
# Out:
# After optional cleanup: (2072, 4)
#                                                 txid  \
# 0  002740a49e16fc127b0a58a887e5ad77cc4d5114a38aa6...
# 1  002eaecebf435e9bc3e2f3c4804ee6dd89c1dc342585d2...
# 2  0038cd4166d80a95d6bf1420beb9d16c9fb5cec19fa31f...
# 3  0083abb19ca6ce1ff1dd55ffa6531fe4d88d3ec884d93e...
# 4  00934630d88a064f60a9d294de072d5fe49620f2d6d727...
#
#                                  from                                  to  \
# 0  3HLqRkgagCCeChBBmWuDkp54YR1LEz7NuK  17AuTmGhZ4HBoJtntpN9n6vHkP5LNnrt5q
# 1  3JEirUZxifRHf7FCY2Z79e3k8FMgGM9ehY  1L14Rw9G4P173tTZdMKsFPpMNY9WdiLKK7
# 2  36tGwveXwuEnmagxrraUv2XKJXeAEzP9iB  1G1yQeKMY8mH1H5v1EbmaSegpBML8T8LuR
# 3  3F14ooo4Z4BchZrFNSxF5jgssMjJcKPfay  1PsMd9HzNxfyFNRQRxsjjvvzX48EmZVn9n
# 4  3A5zJnUeZqqjrNJCAZZkKYxh6ZgdcAKps3  1Pvw3xFhAS2i58fSdSJ7ZuHXHLSe62KcKx
#
#       amount
# 0   5.850062
# 1   7.482093
# 2   7.586615
# 3  13.204210
# 4   5.716555

# %%
# Normalize txids and prep list (code)
def normalize_txid(x) -> str:
    if pd.isna(x):
        return ""
    s = str(x).strip()
    if s.lower().startswith("0x"):
        s = s[2:]
    return s.upper()

df["txid_norm"] = df["txid"].apply(normalize_txid)
unique_txids: List[str] = sorted(set(t for t in df["txid_norm"].tolist() if t))

print("Unique normalized txids:", len(unique_txids))
df[["txid", "txid_norm"]].head(10)
# Out:
# Unique normalized txids: 2072
#                                                 txid  \
# 0  002740a49e16fc127b0a58a887e5ad77cc4d5114a38aa6...
# 1  002eaecebf435e9bc3e2f3c4804ee6dd89c1dc342585d2...
# 2  0038cd4166d80a95d6bf1420beb9d16c9fb5cec19fa31f...
# 3  0083abb19ca6ce1ff1dd55ffa6531fe4d88d3ec884d93e...
# 4  00934630d88a064f60a9d294de072d5fe49620f2d6d727...
# 5  00d4189eca25abcf1381bff4db78db8a8edf8f11c5deb0...
# 6  00e43489afb85a0d3bd05f3a30b2280416d7d333d52840...
# 7  00fa784235855c1923e85557be5c5b5909eadcbd199352...
# 8  0113e56efa662e7afb75ab00d3494cbd573e6334db8b61...
# 9  011c0366033ac9d0a5ca5a878a3f16f65495942b2a50d1...
#
#                                            txid_norm
# 0  002740A49E16FC127B0A58A887E5AD77CC4D5114A38AA6...
# 1  002EAECEBF435E9BC3E2F3C4804EE6DD89C1DC342585D2...
# 2  0038CD4166D80A95D6BF1420BEB9D16C9FB5CEC19FA31F...
# 3  0083ABB19CA6CE1FF1DD55FFA6531FE4D88D3EC884D93E...
# 4  00934630D88A064F60A9D294DE072D5FE49620F2D6D727...
# 5  00D4189ECA25ABCF1381BFF4DB78DB8A8EDF8F11C5DEB0...
# 6  00E43489AFB85A0D3BD05F3A30B2280416D7D333D52840...
# 7  00FA784235855C1923E85557BE5C5B5909EADCBD199352...
# 8  0113E56EFA662E7AFB75AB00D3494CBD573E6334DB8B61...
# 9  011C0366033AC9D0A5CA5A878A3F16F65495942B2A50D1...

# %%
gcloud auth application-default login
# Out:
#   Cell In[7], line 1
#     gcloud auth application-default login
#            ^
# SyntaxError: invalid syntax

# %%
## Initialize BigQuery client (code) run 'gcloud auth application-default login' in conda 
BQ_LOCATION = "US"  # required for bigquery-public-data (US)
client = None
if not DISABLE_BQ and unique_txids:
    try:
        client = get_bigquery_client(BQ_PROJECT_ID)
        _ = client.query("SELECT 1").result()  # sanity check
        print("BigQuery client ready; project:", getattr(client, "project", BQ_PROJECT_ID))
    except Exception as e:
        print("BigQuery not available:", e)
        client = None
else:
    print("BigQuery disabled or no txids; timestamps will be blank.")
# Out:
# BigQuery client ready; project: bitfinex-hack-tracing

# %%
from google.cloud import bigquery

TABLE = "bigquery-public-data.crypto_bitcoin.transactions"

def get_hash_field_type():
    ref = bigquery.TableReference.from_string(TABLE)
    tbl = client.get_table(ref)
    for f in tbl.schema:
        if f.name == "hash":
            return f.field_type
    raise RuntimeError("No 'hash' column found")

hash_type = get_hash_field_type()
print("hash column type:", hash_type)
# Out:
# hash column type: STRING

# %%
# Helpers (normalizers for both paths)
def norm_hex_lower_list(txids):
    out = []
    for t in txids:
        if not t:
            continue
        s = str(t).strip()
        if s.lower().startswith("0x"):
            s = s[2:]
        try:
            bytes.fromhex(s)
            out.append(s.lower())
        except ValueError:
            pass
    return out

def to_hash_bytes_list(txids):
    out = []
    for t in txids:
        if not t:
            continue
        s = str(t).strip()
        if s.lower().startswith("0x"):
            s = s[2:]
        try:
            b = bytes.fromhex(s)
            out.append(b[::-1])  # to stored endianness if BYTES
        except ValueError:
            pass
    return out

# %%
# Run a tiny probe first
probe = fetch_tx_timestamps_bytes(client, unique_txids[:20], batch_size=10, location=BQ_LOCATION, timeout=60)
print("Probe:", len(probe), list(probe.items())[:3])
# Out:
# Fetching 20 txids (batch=10) …
# Batch 0-10 (hashes=10) … FAILED: 400 No matching signature for operator IN UNNEST for argument types: STRING, ARRAY<BYTES> at [4:14]; reason: invalidQuery, location: query, message: No matching signature for operator IN UNNEST for argument types: STRING, ARRAY<BYTES> at [4:14]
#
# Location: US
# Job ID: df4733fd-f342-417c-9c5b-131d3ff17964
#
# Batch 10-20 (hashes=10) … FAILED: 400 No matching signature for operator IN UNNEST for argument types: STRING, ARRAY<BYTES> at [4:14]; reason: invalidQuery, location: query, message: No matching signature for operator IN UNNEST for argument types: STRING, ARRAY<BYTES> at [4:14]
#
# Location: US
# Job ID: 0599ebe9-8b57-4a11-b4bb-208df1639369
#
# Done. Fetched 0 timestamps.
# Probe: 0 []

# %%
# Merge timestamps and optional datetime column (code)
out = df.copy()
out[TIMESTAMP_COL] = out["txid_norm"].map(txid_to_ts).fillna("")
# Optional: a parsed datetime column for convenience
try:
    out["timestamp_dt"] = pd.to_datetime(out[TIMESTAMP_COL], utc=True, errors="coerce")
except Exception:
    pass

out = out.drop(columns=["txid_norm"])
out.head(10)

# %%
Cell 11 — Write outputs (CSV and XLSX) (code)
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)
csv_path = OUTPUT_DIR / "transactions_with_timestamps.csv"
xlsx_path = OUTPUT_DIR / "transactions_with_timestamps.xlsx"

out.to_csv(csv_path, index=False)
try:
    out.to_excel(xlsx_path, index=False)
except Exception as e:
    print("Excel write skipped:", e)

csv_path, xlsx_path

# %%
Cell 12 — Quick validation and next steps (code)
total = len(out)
missing = int(out[TIMESTAMP_COL].eq("").sum())
print(f"Rows: {total}  |  Missing timestamps: {missing}  |  Coverage: {100*(total-missing)/max(1,total):.1f}%")
out.sample(min(5, total), random_state=42)
